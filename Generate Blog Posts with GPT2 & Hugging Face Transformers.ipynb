# %% [markdown]
# # ***1/ Install and Import Dependencies***

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %% [markdown]
# # ***2/ Load Model***

# %%
tokenizer.decode(tokenizer.eos_token_id)
# Out:
# '<|endoftext|>'

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large')
model = GPT2LMHeadModel.from_pretrained("gpt2-large",pad_token_id=tokenizer.eos_token_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %% [markdown]
# # ***3/Tokenize Sentences***

# %%
sentence = " Introducing LLaMA: A foundational, 65-billion-parameter large language model "
input_ids = tokenizer.encode(sentence, return_tensors='pt')

# %%
input_ids[0][0]
# Out:
# tensor(11036)

# %%
tokenizer.decode(input_ids[0])
# Out:
# ' Introducing LLaMA: A foundational, 65-billion-parameter large language model '

# %% [markdown]
# # ***4/ Generate and decode text***

# %%
output = model.generate (input_ids, max_length = 500, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)

# %%
len(output[0])
# Out:
# 137

# %%
tokenizer.decode(output[0], skip_special_tokens=True)
# Out:
# ' Introducing LLaMA: A foundational, 65-billion-parameter large language model 《LLaMAA》\n\nThe goal of this paper is to present a large-scale, high-performance, general-purpose model of language evolution. The model is based on the LALMA (Large Language Algorithm for Adaptive Evolutionary Computation) algorithm, which has been used extensively in the field of evolutionary computation. This paper describes the design and implementation of the model, as well as some of its key properties. We also present the results of a series of experiments that demonstrate the robustness of our model to a wide range of experimental conditions.'

# %% [markdown]
# ## 5/ Output Result ***bold text***

# %%
text = tokenizer.decode(output[0], skip_special_tokens=True)

# %%
with open('LammaPaper.txt','w') as f:
  f.write(text)
